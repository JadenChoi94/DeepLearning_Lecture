# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint,EarlyStopping

import pandas as pd
import numpy
import tensorflow as tf
import os

# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

df_pre = pd.read_csv('../data/wine.csv', header=None)
df = df_pre.sample(frac=0.15)

dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
           optimizer='adam',
           metrics=['accuracy'])

# %%
# 모델 저장 폴더 만들기
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, callbacks=[early_stopping_callback,checkpointer])

print("/n Accurancy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# Epoch 00001: val_loss improved from inf to 0.04951, saving model to ./model/01-0.0495.hdf5
#
# Epoch 00002: val_loss improved from 0.04951 to 0.04947, saving model to ./model/02-0.0495.hdf5
#
# Epoch 00003: val_loss did not improve from 0.04947
#
# Epoch 00004: val_loss did not improve from 0.04947
#
# Epoch 00005: val_loss did not improve from 0.04947
#
# Epoch 00006: val_loss did not improve from 0.04947
#
# Epoch 00007: val_loss did not improve from 0.04947
#
# Epoch 00008: val_loss did not improve from 0.04947
#
# Epoch 00009: val_loss did not improve from 0.04947
#
# Epoch 00010: val_loss did not improve from 0.04947
#
# Epoch 00011: val_loss did not improve from 0.04947
#
# Epoch 00012: val_loss did not improve from 0.04947
#
# Epoch 00013: val_loss did not improve from 0.04947
#
# Epoch 00014: val_loss did not improve from 0.04947
#
# Epoch 00015: val_loss did not improve from 0.04947
#
# Epoch 00016: val_loss did not improve from 0.04947
#
# Epoch 00017: val_loss did not improve from 0.04947
#
# Epoch 00018: val_loss did not improve from 0.04947
#
# Epoch 00019: val_loss did not improve from 0.04947
#
# Epoch 00020: val_loss did not improve from 0.04947
#
# Epoch 00021: val_loss improved from 0.04947 to 0.04938, saving model to ./model/21-0.0494.hdf5
#
# Epoch 00022: val_loss did not improve from 0.04938
#
# Epoch 00023: val_loss did not improve from 0.04938
#
# Epoch 00024: val_loss did not improve from 0.04938
#
# Epoch 00025: val_loss did not improve from 0.04938
#
# Epoch 00026: val_loss did not improve from 0.04938
#
# Epoch 00027: val_loss did not improve from 0.04938
#
# Epoch 00028: val_loss did not improve from 0.04938
#
# Epoch 00029: val_loss did not improve from 0.04938
#
# Epoch 00030: val_loss did not improve from 0.04938
#
# Epoch 00031: val_loss did not improve from 0.04938
#
# Epoch 00032: val_loss did not improve from 0.04938
#
# Epoch 00033: val_loss did not improve from 0.04938
#
# Epoch 00034: val_loss did not improve from 0.04938
#
# Epoch 00035: val_loss did not improve from 0.04938
#
# Epoch 00036: val_loss did not improve from 0.04938
#
# Epoch 00037: val_loss did not improve from 0.04938
#
# Epoch 00038: val_loss did not improve from 0.04938
#
# Epoch 00039: val_loss did not improve from 0.04938
#
# Epoch 00040: val_loss did not improve from 0.04938
#
# Epoch 00041: val_loss did not improve from 0.04938
#
# Epoch 00042: val_loss did not improve from 0.04938
#
# Epoch 00043: val_loss did not improve from 0.04938
#
# Epoch 00044: val_loss did not improve from 0.04938
#
# Epoch 00045: val_loss did not improve from 0.04938
#
# Epoch 00046: val_loss did not improve from 0.04938
#
# Epoch 00047: val_loss did not improve from 0.04938
#
# Epoch 00048: val_loss did not improve from 0.04938
#
# Epoch 00049: val_loss did not improve from 0.04938
#
# Epoch 00050: val_loss did not improve from 0.04938
#
# Epoch 00051: val_loss did not improve from 0.04938
#
# Epoch 00052: val_loss did not improve from 0.04938
#
# Epoch 00053: val_loss did not improve from 0.04938
#
# Epoch 00054: val_loss did not improve from 0.04938
#
# Epoch 00055: val_loss did not improve from 0.04938
#
# Epoch 00056: val_loss did not improve from 0.04938
#
# Epoch 00057: val_loss did not improve from 0.04938
#
# Epoch 00058: val_loss did not improve from 0.04938
#
# Epoch 00059: val_loss did not improve from 0.04938
#
# Epoch 00060: val_loss did not improve from 0.04938
#
# Epoch 00061: val_loss did not improve from 0.04938
#
# Epoch 00062: val_loss did not improve from 0.04938
#
# Epoch 00063: val_loss did not improve from 0.04938
#
# Epoch 00064: val_loss did not improve from 0.04938
#
# Epoch 00065: val_loss did not improve from 0.04938
#
# Epoch 00066: val_loss did not improve from 0.04938
#
# Epoch 00067: val_loss did not improve from 0.04938
#
# Epoch 00068: val_loss did not improve from 0.04938
#
# Epoch 00069: val_loss did not improve from 0.04938
#
# Epoch 00070: val_loss did not improve from 0.04938
#
# Epoch 00071: val_loss did not improve from 0.04938
#
# Epoch 00072: val_loss did not improve from 0.04938
#
# Epoch 00073: val_loss did not improve from 0.04938
#
# Epoch 00074: val_loss did not improve from 0.04938
#
# Epoch 00075: val_loss did not improve from 0.04938
#
# Epoch 00076: val_loss did not improve from 0.04938
#
# Epoch 00077: val_loss did not improve from 0.04938
#
# Epoch 00078: val_loss did not improve from 0.04938
#
# Epoch 00079: val_loss did not improve from 0.04938
#
# Epoch 00080: val_loss did not improve from 0.04938
#
# Epoch 00081: val_loss did not improve from 0.04938
#
# Epoch 00082: val_loss did not improve from 0.04938
#
# Epoch 00083: val_loss did not improve from 0.04938
#
# Epoch 00084: val_loss did not improve from 0.04938
#
# Epoch 00085: val_loss did not improve from 0.04938
#
# Epoch 00086: val_loss did not improve from 0.04938
#
# Epoch 00087: val_loss did not improve from 0.04938
#
# Epoch 00088: val_loss did not improve from 0.04938
#
# Epoch 00089: val_loss did not improve from 0.04938
#
# Epoch 00090: val_loss did not improve from 0.04938
#
# Epoch 00091: val_loss did not improve from 0.04938
#
# Epoch 00092: val_loss did not improve from 0.04938
#
# Epoch 00093: val_loss did not improve from 0.04938
#
# Epoch 00094: val_loss did not improve from 0.04938
#
# Epoch 00095: val_loss did not improve from 0.04938
#
# Epoch 00096: val_loss did not improve from 0.04938
#
# Epoch 00097: val_loss did not improve from 0.04938
#
# Epoch 00098: val_loss did not improve from 0.04938
#
# Epoch 00099: val_loss did not improve from 0.04938
#
# Epoch 00100: val_loss did not improve from 0.04938
#
# Epoch 00101: val_loss did not improve from 0.04938
#
# Epoch 00102: val_loss did not improve from 0.04938
#
# Epoch 00103: val_loss did not improve from 0.04938
#
# Epoch 00104: val_loss did not improve from 0.04938
#
# Epoch 00105: val_loss did not improve from 0.04938
#
# Epoch 00106: val_loss did not improve from 0.04938
#
# Epoch 00107: val_loss did not improve from 0.04938
#
# Epoch 00108: val_loss did not improve from 0.04938
#
# Epoch 00109: val_loss did not improve from 0.04938
#
# Epoch 00110: val_loss did not improve from 0.04938
#
# Epoch 00111: val_loss did not improve from 0.04938
#
# Epoch 00112: val_loss did not improve from 0.04938
#
# Epoch 00113: val_loss did not improve from 0.04938
#
# Epoch 00114: val_loss did not improve from 0.04938
#
# Epoch 00115: val_loss did not improve from 0.04938
#
# Epoch 00116: val_loss did not improve from 0.04938
#
# Epoch 00117: val_loss did not improve from 0.04938
#
# Epoch 00118: val_loss did not improve from 0.04938
#
# Epoch 00119: val_loss did not improve from 0.04938
#
# Epoch 00120: val_loss did not improve from 0.04938
#
# Epoch 00121: val_loss did not improve from 0.04938
# 975/975 [==============================] - 0s 0us/step
# /n Accurancy: 0.9959
