# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint

import pandas as pd
import numpy
import os
import tensorflow as tf

# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

df_pre = pd.read_csv('../data/wine.csv', header=None)
df = df_pre.sample(frac=1)

dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]
# Out:
# Using TensorFlow backend.

# %%
# 모델의 설정
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# 모델 저장 폴더 설정
MODEL_DIR = './model2/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

# 모델 저장 조건 설정
modelpath="./model2/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True) #verbose 화면에 띄우때

# 모델 실행 및 저장
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])#verbose = 0  화면에 안띄운다.
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0812 11:16:28.395318  6092 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0812 11:16:28.395318  6092 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0812 11:16:28.395318  6092 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0812 11:16:28.442519  6092 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0812 11:16:28.457520  6092 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0812 11:16:28.461520  6092 deprecation.py:323] From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0812 11:16:28.636724  6092 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 00001: val_loss improved from inf to 0.31099, saving model to ./model2/01-0.3110.hdf5
#
# Epoch 00002: val_loss improved from 0.31099 to 0.25234, saving model to ./model2/02-0.2523.hdf5
#
# Epoch 00003: val_loss improved from 0.25234 to 0.21341, saving model to ./model2/03-0.2134.hdf5
#
# Epoch 00004: val_loss improved from 0.21341 to 0.20457, saving model to ./model2/04-0.2046.hdf5
#
# Epoch 00005: val_loss improved from 0.20457 to 0.19659, saving model to ./model2/05-0.1966.hdf5
#
# Epoch 00006: val_loss improved from 0.19659 to 0.18594, saving model to ./model2/06-0.1859.hdf5
#
# Epoch 00007: val_loss improved from 0.18594 to 0.18055, saving model to ./model2/07-0.1806.hdf5
#
# Epoch 00008: val_loss improved from 0.18055 to 0.18001, saving model to ./model2/08-0.1800.hdf5
#
# Epoch 00009: val_loss improved from 0.18001 to 0.17961, saving model to ./model2/09-0.1796.hdf5
#
# Epoch 00010: val_loss improved from 0.17961 to 0.17665, saving model to ./model2/10-0.1766.hdf5
#
# Epoch 00011: val_loss improved from 0.17665 to 0.16661, saving model to ./model2/11-0.1666.hdf5
#
# Epoch 00012: val_loss improved from 0.16661 to 0.16322, saving model to ./model2/12-0.1632.hdf5
#
# Epoch 00013: val_loss did not improve from 0.16322
#
# Epoch 00014: val_loss improved from 0.16322 to 0.15823, saving model to ./model2/14-0.1582.hdf5
#
# Epoch 00015: val_loss improved from 0.15823 to 0.15698, saving model to ./model2/15-0.1570.hdf5
#
# Epoch 00016: val_loss improved from 0.15698 to 0.15131, saving model to ./model2/16-0.1513.hdf5
#
# Epoch 00017: val_loss improved from 0.15131 to 0.14842, saving model to ./model2/17-0.1484.hdf5
#
# Epoch 00018: val_loss improved from 0.14842 to 0.14623, saving model to ./model2/18-0.1462.hdf5
#
# Epoch 00019: val_loss improved from 0.14623 to 0.14354, saving model to ./model2/19-0.1435.hdf5
#
# Epoch 00020: val_loss did not improve from 0.14354
#
# Epoch 00021: val_loss improved from 0.14354 to 0.13691, saving model to ./model2/21-0.1369.hdf5
#
# Epoch 00022: val_loss improved from 0.13691 to 0.13394, saving model to ./model2/22-0.1339.hdf5
#
# Epoch 00023: val_loss did not improve from 0.13394
#
# Epoch 00024: val_loss improved from 0.13394 to 0.12787, saving model to ./model2/24-0.1279.hdf5
#
# Epoch 00025: val_loss improved from 0.12787 to 0.12602, saving model to ./model2/25-0.1260.hdf5
#
# Epoch 00026: val_loss improved from 0.12602 to 0.12112, saving model to ./model2/26-0.1211.hdf5
#
# Epoch 00027: val_loss did not improve from 0.12112
#
# Epoch 00028: val_loss improved from 0.12112 to 0.11762, saving model to ./model2/28-0.1176.hdf5
#
# Epoch 00029: val_loss did not improve from 0.11762
#
# Epoch 00030: val_loss improved from 0.11762 to 0.11228, saving model to ./model2/30-0.1123.hdf5
#
# Epoch 00031: val_loss did not improve from 0.11228
#
# Epoch 00032: val_loss improved from 0.11228 to 0.11010, saving model to ./model2/32-0.1101.hdf5
#
# Epoch 00033: val_loss did not improve from 0.11010
#
# Epoch 00034: val_loss did not improve from 0.11010
#
# Epoch 00035: val_loss improved from 0.11010 to 0.10156, saving model to ./model2/35-0.1016.hdf5
#
# Epoch 00036: val_loss did not improve from 0.10156
#
# Epoch 00037: val_loss improved from 0.10156 to 0.09774, saving model to ./model2/37-0.0977.hdf5
#
# Epoch 00038: val_loss improved from 0.09774 to 0.09459, saving model to ./model2/38-0.0946.hdf5
#
# Epoch 00039: val_loss improved from 0.09459 to 0.09287, saving model to ./model2/39-0.0929.hdf5
#
# Epoch 00040: val_loss did not improve from 0.09287
#
# Epoch 00041: val_loss improved from 0.09287 to 0.08992, saving model to ./model2/41-0.0899.hdf5
#
# Epoch 00042: val_loss improved from 0.08992 to 0.08672, saving model to ./model2/42-0.0867.hdf5
#
# Epoch 00043: val_loss improved from 0.08672 to 0.08588, saving model to ./model2/43-0.0859.hdf5
#
# Epoch 00044: val_loss improved from 0.08588 to 0.08565, saving model to ./model2/44-0.0856.hdf5
#
# Epoch 00045: val_loss improved from 0.08565 to 0.08516, saving model to ./model2/45-0.0852.hdf5
#
# Epoch 00046: val_loss improved from 0.08516 to 0.08190, saving model to ./model2/46-0.0819.hdf5
#
# Epoch 00047: val_loss did not improve from 0.08190
#
# Epoch 00048: val_loss did not improve from 0.08190
#
# Epoch 00049: val_loss improved from 0.08190 to 0.07787, saving model to ./model2/49-0.0779.hdf5
#
# Epoch 00050: val_loss did not improve from 0.07787
#
# Epoch 00051: val_loss improved from 0.07787 to 0.07684, saving model to ./model2/51-0.0768.hdf5
#
# Epoch 00052: val_loss improved from 0.07684 to 0.07555, saving model to ./model2/52-0.0755.hdf5
#
# Epoch 00053: val_loss did not improve from 0.07555
#
# Epoch 00054: val_loss did not improve from 0.07555
#
# Epoch 00055: val_loss did not improve from 0.07555
#
# Epoch 00056: val_loss did not improve from 0.07555
#
# Epoch 00057: val_loss improved from 0.07555 to 0.07074, saving model to ./model2/57-0.0707.hdf5
#
# Epoch 00058: val_loss did not improve from 0.07074
#
# Epoch 00059: val_loss did not improve from 0.07074
#
# Epoch 00060: val_loss improved from 0.07074 to 0.06799, saving model to ./model2/60-0.0680.hdf5
#
# Epoch 00061: val_loss did not improve from 0.06799
#
# Epoch 00062: val_loss did not improve from 0.06799
#
# Epoch 00063: val_loss improved from 0.06799 to 0.06539, saving model to ./model2/63-0.0654.hdf5
#
# Epoch 00064: val_loss did not improve from 0.06539
#
# Epoch 00065: val_loss did not improve from 0.06539
#
# Epoch 00066: val_loss improved from 0.06539 to 0.06348, saving model to ./model2/66-0.0635.hdf5
#
# Epoch 00067: val_loss did not improve from 0.06348
#
# Epoch 00068: val_loss did not improve from 0.06348
#
# Epoch 00069: val_loss did not improve from 0.06348
#
# Epoch 00070: val_loss improved from 0.06348 to 0.06099, saving model to ./model2/70-0.0610.hdf5
#
# Epoch 00071: val_loss did not improve from 0.06099
#
# Epoch 00072: val_loss did not improve from 0.06099
#
# Epoch 00073: val_loss did not improve from 0.06099
#
# Epoch 00074: val_loss did not improve from 0.06099
#
# Epoch 00075: val_loss improved from 0.06099 to 0.06077, saving model to ./model2/75-0.0608.hdf5
#
# Epoch 00076: val_loss did not improve from 0.06077
#
# Epoch 00077: val_loss improved from 0.06077 to 0.05882, saving model to ./model2/77-0.0588.hdf5
#
# Epoch 00078: val_loss did not improve from 0.05882
#
# Epoch 00079: val_loss did not improve from 0.05882
#
# Epoch 00080: val_loss did not improve from 0.05882
#
# Epoch 00081: val_loss improved from 0.05882 to 0.05869, saving model to ./model2/81-0.0587.hdf5
#
# Epoch 00082: val_loss did not improve from 0.05869
#
# Epoch 00083: val_loss did not improve from 0.05869
#
# Epoch 00084: val_loss did not improve from 0.05869
#
# Epoch 00085: val_loss did not improve from 0.05869
#
# Epoch 00086: val_loss improved from 0.05869 to 0.05733, saving model to ./model2/86-0.0573.hdf5
#
# Epoch 00087: val_loss improved from 0.05733 to 0.05668, saving model to ./model2/87-0.0567.hdf5
#
# Epoch 00088: val_loss improved from 0.05668 to 0.05482, saving model to ./model2/88-0.0548.hdf5
#
# Epoch 00089: val_loss did not improve from 0.05482
#
# Epoch 00090: val_loss did not improve from 0.05482
#
# Epoch 00091: val_loss did not improve from 0.05482
#
# Epoch 00092: val_loss improved from 0.05482 to 0.05426, saving model to ./model2/92-0.0543.hdf5
#
# Epoch 00093: val_loss did not improve from 0.05426
#
# Epoch 00094: val_loss did not improve from 0.05426
#
# Epoch 00095: val_loss did not improve from 0.05426
#
# Epoch 00096: val_loss did not improve from 0.05426
#
# Epoch 00097: val_loss improved from 0.05426 to 0.05322, saving model to ./model2/97-0.0532.hdf5
#
# Epoch 00098: val_loss improved from 0.05322 to 0.05318, saving model to ./model2/98-0.0532.hdf5
#
# Epoch 00099: val_loss did not improve from 0.05318
#
# Epoch 00100: val_loss did not improve from 0.05318
#
# Epoch 00101: val_loss did not improve from 0.05318
#
# Epoch 00102: val_loss improved from 0.05318 to 0.05295, saving model to ./model2/102-0.0529.hdf5
#
# Epoch 00103: val_loss did not improve from 0.05295
#
# Epoch 00104: val_loss did not improve from 0.05295
#
# Epoch 00105: val_loss did not improve from 0.05295
#
# Epoch 00106: val_loss did not improve from 0.05295
#
# Epoch 00107: val_loss did not improve from 0.05295
#
# Epoch 00108: val_loss did not improve from 0.05295
#
# Epoch 00109: val_loss did not improve from 0.05295
#
# Epoch 00110: val_loss did not improve from 0.05295
#
# Epoch 00111: val_loss improved from 0.05295 to 0.05221, saving model to ./model2/111-0.0522.hdf5
#
# Epoch 00112: val_loss did not improve from 0.05221
#
# Epoch 00113: val_loss improved from 0.05221 to 0.05160, saving model to ./model2/113-0.0516.hdf5
#
# Epoch 00114: val_loss did not improve from 0.05160
#
# Epoch 00115: val_loss did not improve from 0.05160
#
# Epoch 00116: val_loss improved from 0.05160 to 0.05023, saving model to ./model2/116-0.0502.hdf5
# Epoch 00117: val_loss did not improve from 0.05023
#
# Epoch 00118: val_loss did not improve from 0.05023
#
# Epoch 00119: val_loss did not improve from 0.05023
#
# Epoch 00120: val_loss did not improve from 0.05023
#
# Epoch 00121: val_loss did not improve from 0.05023
#
# Epoch 00122: val_loss did not improve from 0.05023
#
# Epoch 00123: val_loss did not improve from 0.05023
#
# Epoch 00124: val_loss did not improve from 0.05023
#
# Epoch 00125: val_loss did not improve from 0.05023
#
# Epoch 00126: val_loss did not improve from 0.05023
#
# Epoch 00127: val_loss did not improve from 0.05023
#
# Epoch 00128: val_loss improved from 0.05023 to 0.04926, saving model to ./model2/128-0.0493.hdf5
#
# Epoch 00129: val_loss did not improve from 0.04926
#
# Epoch 00130: val_loss did not improve from 0.04926
#
# Epoch 00131: val_loss did not improve from 0.04926
#
# Epoch 00132: val_loss did not improve from 0.04926
#
# Epoch 00133: val_loss did not improve from 0.04926
#
# Epoch 00134: val_loss did not improve from 0.04926
#
# Epoch 00135: val_loss did not improve from 0.04926
#
# Epoch 00136: val_loss did not improve from 0.04926
#
# Epoch 00137: val_loss did not improve from 0.04926
#
# Epoch 00138: val_loss did not improve from 0.04926
#
# Epoch 00139: val_loss improved from 0.04926 to 0.04792, saving model to ./model2/139-0.0479.hdf5
#
# Epoch 00140: val_loss did not improve from 0.04792
#
# Epoch 00141: val_loss did not improve from 0.04792
#
# Epoch 00142: val_loss did not improve from 0.04792
#
# Epoch 00143: val_loss did not improve from 0.04792
#
# Epoch 00144: val_loss did not improve from 0.04792
#
# Epoch 00145: val_loss did not improve from 0.04792
#
# Epoch 00146: val_loss did not improve from 0.04792
#
# Epoch 00147: val_loss did not improve from 0.04792
#
# Epoch 00148: val_loss did not improve from 0.04792
#
# Epoch 00149: val_loss did not improve from 0.04792
#
# Epoch 00150: val_loss did not improve from 0.04792
#
# Epoch 00151: val_loss did not improve from 0.04792
#
# Epoch 00152: val_loss did not improve from 0.04792
#
# Epoch 00153: val_loss did not improve from 0.04792
#
# Epoch 00154: val_loss did not improve from 0.04792
#
# Epoch 00155: val_loss did not improve from 0.04792
#
# Epoch 00156: val_loss did not improve from 0.04792
#
# Epoch 00157: val_loss did not improve from 0.04792
#
# Epoch 00158: val_loss did not improve from 0.04792
#
# Epoch 00159: val_loss did not improve from 0.04792
#
# Epoch 00160: val_loss did not improve from 0.04792
#
# Epoch 00161: val_loss did not improve from 0.04792
#
# Epoch 00162: val_loss did not improve from 0.04792
#
# Epoch 00163: val_loss did not improve from 0.04792
#
# Epoch 00164: val_loss improved from 0.04792 to 0.04766, saving model to ./model2/164-0.0477.hdf5
#
# Epoch 00165: val_loss did not improve from 0.04766
#
# Epoch 00166: val_loss improved from 0.04766 to 0.04737, saving model to ./model2/166-0.0474.hdf5
#
# Epoch 00167: val_loss did not improve from 0.04737
#
# Epoch 00168: val_loss did not improve from 0.04737
#
# Epoch 00169: val_loss did not improve from 0.04737
#
# Epoch 00170: val_loss did not improve from 0.04737
#
# Epoch 00171: val_loss did not improve from 0.04737
#
# Epoch 00172: val_loss improved from 0.04737 to 0.04626, saving model to ./model2/172-0.0463.hdf5
#
# Epoch 00173: val_loss did not improve from 0.04626
#
# Epoch 00174: val_loss did not improve from 0.04626
#
# Epoch 00175: val_loss did not improve from 0.04626
#
# Epoch 00176: val_loss did not improve from 0.04626
#
# Epoch 00177: val_loss did not improve from 0.04626
#
# Epoch 00178: val_loss did not improve from 0.04626
#
# Epoch 00179: val_loss improved from 0.04626 to 0.04514, saving model to ./model2/179-0.0451.hdf5
#
# Epoch 00180: val_loss did not improve from 0.04514
#
# Epoch 00181: val_loss did not improve from 0.04514
#
# Epoch 00182: val_loss did not improve from 0.04514
#
# Epoch 00183: val_loss did not improve from 0.04514
#
# Epoch 00184: val_loss did not improve from 0.04514
#
# Epoch 00185: val_loss did not improve from 0.04514
#
# Epoch 00186: val_loss did not improve from 0.04514
#
# Epoch 00187: val_loss did not improve from 0.04514
#
# Epoch 00188: val_loss did not improve from 0.04514
#
# Epoch 00189: val_loss did not improve from 0.04514
#
# Epoch 00190: val_loss did not improve from 0.04514
#
# Epoch 00191: val_loss did not improve from 0.04514
#
# Epoch 00192: val_loss did not improve from 0.04514
#
# Epoch 00193: val_loss did not improve from 0.04514
#
# Epoch 00194: val_loss improved from 0.04514 to 0.04458, saving model to ./model2/194-0.0446.hdf5
#
# Epoch 00195: val_loss did not improve from 0.04458
#
# Epoch 00196: val_loss did not improve from 0.04458
#
# Epoch 00197: val_loss did not improve from 0.04458
#
# Epoch 00198: val_loss did not improve from 0.04458
#
# Epoch 00199: val_loss did not improve from 0.04458
#
# Epoch 00200: val_loss did not improve from 0.04458
