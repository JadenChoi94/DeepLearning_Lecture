# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint

import pandas as pd
import numpy
import os
import tensorflow as tf

# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

df_pre = pd.read_csv('../data/wine.csv', header=None)
df = df_pre.sample(frac=1)

dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]
# Out:
# Using TensorFlow backend.

# %%
# 모델의 설정
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# 모델 저장 폴더 설정
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

# 모델 저장 조건 설정
modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1) #verbose 화면에 띄우때

# 모델 실행 및 저장
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])#verbose = 0  화면에 안띄운다.
# Out:
# Epoch 00001: saving model to ./model/01-0.5292.hdf5
#
# Epoch 00002: saving model to ./model/02-0.3353.hdf5
#
# Epoch 00003: saving model to ./model/03-0.3166.hdf5
#
# Epoch 00004: saving model to ./model/04-0.3104.hdf5
#
# Epoch 00005: saving model to ./model/05-0.3034.hdf5
#
# Epoch 00006: saving model to ./model/06-0.2870.hdf5
#
# Epoch 00007: saving model to ./model/07-0.2670.hdf5
#
# Epoch 00008: saving model to ./model/08-0.2444.hdf5
#
# Epoch 00009: saving model to ./model/09-0.2274.hdf5
#
# Epoch 00010: saving model to ./model/10-0.2176.hdf5
#
# Epoch 00011: saving model to ./model/11-0.2106.hdf5
#
# Epoch 00012: saving model to ./model/12-0.2060.hdf5
#
# Epoch 00013: saving model to ./model/13-0.2075.hdf5
#
# Epoch 00014: saving model to ./model/14-0.1978.hdf5
#
# Epoch 00015: saving model to ./model/15-0.1966.hdf5
#
# Epoch 00016: saving model to ./model/16-0.1899.hdf5
#
# Epoch 00017: saving model to ./model/17-0.1869.hdf5
#
# Epoch 00018: saving model to ./model/18-0.1831.hdf5
#
# Epoch 00019: saving model to ./model/19-0.1821.hdf5
#
# Epoch 00020: saving model to ./model/20-0.1784.hdf5
#
# Epoch 00021: saving model to ./model/21-0.1748.hdf5
#
# Epoch 00022: saving model to ./model/22-0.1722.hdf5
#
# Epoch 00023: saving model to ./model/23-0.1693.hdf5
#
# Epoch 00024: saving model to ./model/24-0.1675.hdf5
#
# Epoch 00025: saving model to ./model/25-0.1633.hdf5
#
# Epoch 00026: saving model to ./model/26-0.1644.hdf5
#
# Epoch 00027: saving model to ./model/27-0.1583.hdf5
#
# Epoch 00028: saving model to ./model/28-0.1546.hdf5
#
# Epoch 00029: saving model to ./model/29-0.1610.hdf5
#
# Epoch 00030: saving model to ./model/30-0.1497.hdf5
#
# Epoch 00031: saving model to ./model/31-0.1464.hdf5
#
# Epoch 00032: saving model to ./model/32-0.1434.hdf5
#
# Epoch 00033: saving model to ./model/33-0.1417.hdf5
#
# Epoch 00034: saving model to ./model/34-0.1383.hdf5
#
# Epoch 00035: saving model to ./model/35-0.1381.hdf5
#
# Epoch 00036: saving model to ./model/36-0.1315.hdf5
#
# Epoch 00037: saving model to ./model/37-0.1280.hdf5
#
# Epoch 00038: saving model to ./model/38-0.1238.hdf5
#
# Epoch 00039: saving model to ./model/39-0.1224.hdf5
#
# Epoch 00040: saving model to ./model/40-0.1182.hdf5
#
# Epoch 00041: saving model to ./model/41-0.1184.hdf5
#
# Epoch 00042: saving model to ./model/42-0.1130.hdf5
#
# Epoch 00043: saving model to ./model/43-0.1112.hdf5
#
# Epoch 00044: saving model to ./model/44-0.1072.hdf5
#
# Epoch 00045: saving model to ./model/45-0.1050.hdf5
#
# Epoch 00046: saving model to ./model/46-0.1035.hdf5
#
# Epoch 00047: saving model to ./model/47-0.1037.hdf5
#
# Epoch 00048: saving model to ./model/48-0.0980.hdf5
#
# Epoch 00049: saving model to ./model/49-0.0966.hdf5
#
# Epoch 00050: saving model to ./model/50-0.0941.hdf5
#
# Epoch 00051: saving model to ./model/51-0.0924.hdf5
#
# Epoch 00052: saving model to ./model/52-0.0905.hdf5
#
# Epoch 00053: saving model to ./model/53-0.0979.hdf5
#
# Epoch 00054: saving model to ./model/54-0.0871.hdf5
#
# Epoch 00055: saving model to ./model/55-0.0852.hdf5
#
# Epoch 00056: saving model to ./model/56-0.0866.hdf5
#
# Epoch 00057: saving model to ./model/57-0.0823.hdf5
#
# Epoch 00058: saving model to ./model/58-0.0809.hdf5
#
# Epoch 00059: saving model to ./model/59-0.0833.hdf5
#
# Epoch 00060: saving model to ./model/60-0.0783.hdf5
#
# Epoch 00061: saving model to ./model/61-0.0794.hdf5
#
# Epoch 00062: saving model to ./model/62-0.0768.hdf5
#
# Epoch 00063: saving model to ./model/63-0.0750.hdf5
#
# Epoch 00064: saving model to ./model/64-0.0739.hdf5
#
# Epoch 00065: saving model to ./model/65-0.0728.hdf5
#
# Epoch 00066: saving model to ./model/66-0.0703.hdf5
#
# Epoch 00067: saving model to ./model/67-0.0702.hdf5
#
# Epoch 00068: saving model to ./model/68-0.0702.hdf5
#
# Epoch 00069: saving model to ./model/69-0.0705.hdf5
#
# Epoch 00070: saving model to ./model/70-0.0690.hdf5
#
# Epoch 00071: saving model to ./model/71-0.0688.hdf5
#
# Epoch 00072: saving model to ./model/72-0.0679.hdf5
#
# Epoch 00073: saving model to ./model/73-0.0754.hdf5
#
# Epoch 00074: saving model to ./model/74-0.0749.hdf5
#
# Epoch 00075: saving model to ./model/75-0.0652.hdf5
#
# Epoch 00076: saving model to ./model/76-0.0633.hdf5
#
# Epoch 00077: saving model to ./model/77-0.0630.hdf5
#
# Epoch 00078: saving model to ./model/78-0.0628.hdf5
#
# Epoch 00079: saving model to ./model/79-0.0617.hdf5
#
# Epoch 00080: saving model to ./model/80-0.0631.hdf5
#
# Epoch 00081: saving model to ./model/81-0.0626.hdf5
#
# Epoch 00082: saving model to ./model/82-0.0635.hdf5
#
# Epoch 00083: saving model to ./model/83-0.0636.hdf5
#
# Epoch 00084: saving model to ./model/84-0.0602.hdf5
#
# Epoch 00085: saving model to ./model/85-0.0610.hdf5
#
# Epoch 00086: saving model to ./model/86-0.0605.hdf5
#
# Epoch 00087: saving model to ./model/87-0.0604.hdf5
#
# Epoch 00088: saving model to ./model/88-0.0598.hdf5
#
# Epoch 00089: saving model to ./model/89-0.0598.hdf5
#
# Epoch 00090: saving model to ./model/90-0.0594.hdf5
#
# Epoch 00091: saving model to ./model/91-0.0640.hdf5
#
# Epoch 00092: saving model to ./model/92-0.0587.hdf5
#
# Epoch 00093: saving model to ./model/93-0.0611.hdf5
#
# Epoch 00094: saving model to ./model/94-0.0597.hdf5
#
# Epoch 00095: saving model to ./model/95-0.0582.hdf5
#
# Epoch 00096: saving model to ./model/96-0.0590.hdf5
#
# Epoch 00097: saving model to ./model/97-0.0600.hdf5
#
# Epoch 00098: saving model to ./model/98-0.0578.hdf5
#
# Epoch 00099: saving model to ./model/99-0.0594.hdf5
#
# Epoch 00100: saving model to ./model/100-0.0583.hdf5
#
# Epoch 00101: saving model to ./model/101-0.0591.hdf5
#
# Epoch 00102: saving model to ./model/102-0.0568.hdf5
#
# Epoch 00103: saving model to ./model/103-0.0564.hdf5
#
# Epoch 00104: saving model to ./model/104-0.0562.hdf5
#
# Epoch 00105: saving model to ./model/105-0.0566.hdf5
#
# Epoch 00106: saving model to ./model/106-0.0561.hdf5
#
# Epoch 00107: saving model to ./model/107-0.0547.hdf5
#
# Epoch 00108: saving model to ./model/108-0.0560.hdf5
#
# Epoch 00109: saving model to ./model/109-0.0564.hdf5
#
# Epoch 00110: saving model to ./model/110-0.0556.hdf5
#
# Epoch 00111: saving model to ./model/111-0.0553.hdf5
#
# Epoch 00112: saving model to ./model/112-0.0546.hdf5
#
# Epoch 00113: saving model to ./model/113-0.0566.hdf5
#
# Epoch 00114: saving model to ./model/114-0.0555.hdf5
#
# Epoch 00115: saving model to ./model/115-0.0540.hdf5
#
# Epoch 00116: saving model to ./model/116-0.0543.hdf5
#
# Epoch 00117: saving model to ./model/117-0.0546.hdf5
#
# Epoch 00118: saving model to ./model/118-0.0555.hdf5
#
# Epoch 00119: saving model to ./model/119-0.0567.hdf5
#
# Epoch 00120: saving model to ./model/120-0.0567.hdf5
#
# Epoch 00121: saving model to ./model/121-0.0571.hdf5
#
# Epoch 00122: saving model to ./model/122-0.0560.hdf5
#
# Epoch 00123: saving model to ./model/123-0.0607.hdf5
#
# Epoch 00124: saving model to ./model/124-0.0530.hdf5
#
# Epoch 00125: saving model to ./model/125-0.0578.hdf5
#
# Epoch 00126: saving model to ./model/126-0.0619.hdf5
#
# Epoch 00127: saving model to ./model/127-0.0538.hdf5
#
# Epoch 00128: saving model to ./model/128-0.0578.hdf5
#
# Epoch 00129: saving model to ./model/129-0.0533.hdf5
#
# Epoch 00130: saving model to ./model/130-0.0535.hdf5
#
# Epoch 00131: saving model to ./model/131-0.0523.hdf5
#
# Epoch 00132: saving model to ./model/132-0.0592.hdf5
#
# Epoch 00133: saving model to ./model/133-0.0533.hdf5
#
# Epoch 00134: saving model to ./model/134-0.0533.hdf5
#
# Epoch 00135: saving model to ./model/135-0.0531.hdf5
#
# Epoch 00136: saving model to ./model/136-0.0527.hdf5
#
# Epoch 00137: saving model to ./model/137-0.0533.hdf5
#
# Epoch 00138: saving model to ./model/138-0.0541.hdf5
#
# Epoch 00139: saving model to ./model/139-0.0525.hdf5
#
# Epoch 00140: saving model to ./model/140-0.0531.hdf5
#
# Epoch 00141: saving model to ./model/141-0.0524.hdf5
#
# Epoch 00142: saving model to ./model/142-0.0535.hdf5
#
# Epoch 00143: saving model to ./model/143-0.0549.hdf5
#
# Epoch 00144: saving model to ./model/144-0.0575.hdf5
#
# Epoch 00145: saving model to ./model/145-0.0522.hdf5
#
# Epoch 00146: saving model to ./model/146-0.0518.hdf5
#
# Epoch 00147: saving model to ./model/147-0.0524.hdf5
#
# Epoch 00148: saving model to ./model/148-0.0518.hdf5
#
# Epoch 00149: saving model to ./model/149-0.0527.hdf5
#
# Epoch 00150: saving model to ./model/150-0.0524.hdf5
#
# Epoch 00151: saving model to ./model/151-0.0527.hdf5
#
# Epoch 00152: saving model to ./model/152-0.0532.hdf5
#
# Epoch 00153: saving model to ./model/153-0.0518.hdf5
#
# Epoch 00154: saving model to ./model/154-0.0696.hdf5
# Epoch 00155: saving model to ./model/155-0.0564.hdf5
#
# Epoch 00156: saving model to ./model/156-0.0520.hdf5
#
# Epoch 00157: saving model to ./model/157-0.0526.hdf5
#
# Epoch 00158: saving model to ./model/158-0.0528.hdf5
#
# Epoch 00159: saving model to ./model/159-0.0551.hdf5
#
# Epoch 00160: saving model to ./model/160-0.0522.hdf5
#
# Epoch 00161: saving model to ./model/161-0.0628.hdf5
#
# Epoch 00162: saving model to ./model/162-0.0576.hdf5
#
# Epoch 00163: saving model to ./model/163-0.0549.hdf5
#
# Epoch 00164: saving model to ./model/164-0.0515.hdf5
#
# Epoch 00165: saving model to ./model/165-0.0517.hdf5
#
# Epoch 00166: saving model to ./model/166-0.0631.hdf5
#
# Epoch 00167: saving model to ./model/167-0.0710.hdf5
#
# Epoch 00168: saving model to ./model/168-0.0535.hdf5
#
# Epoch 00169: saving model to ./model/169-0.0534.hdf5
#
# Epoch 00170: saving model to ./model/170-0.0527.hdf5
#
# Epoch 00171: saving model to ./model/171-0.0514.hdf5
#
# Epoch 00172: saving model to ./model/172-0.0559.hdf5
#
# Epoch 00173: saving model to ./model/173-0.0525.hdf5
#
# Epoch 00174: saving model to ./model/174-0.0520.hdf5
#
# Epoch 00175: saving model to ./model/175-0.0513.hdf5
#
# Epoch 00176: saving model to ./model/176-0.0527.hdf5
#
# Epoch 00177: saving model to ./model/177-0.0511.hdf5
#
# Epoch 00178: saving model to ./model/178-0.0511.hdf5
#
# Epoch 00179: saving model to ./model/179-0.0673.hdf5
#
# Epoch 00180: saving model to ./model/180-0.0507.hdf5
#
# Epoch 00181: saving model to ./model/181-0.0513.hdf5
#
# Epoch 00182: saving model to ./model/182-0.0503.hdf5
#
# Epoch 00183: saving model to ./model/183-0.0507.hdf5
#
# Epoch 00184: saving model to ./model/184-0.0502.hdf5
#
# Epoch 00185: saving model to ./model/185-0.0513.hdf5
#
# Epoch 00186: saving model to ./model/186-0.0521.hdf5
#
# Epoch 00187: saving model to ./model/187-0.0498.hdf5
#
# Epoch 00188: saving model to ./model/188-0.0496.hdf5
#
# Epoch 00189: saving model to ./model/189-0.0501.hdf5
#
# Epoch 00190: saving model to ./model/190-0.0501.hdf5
#
# Epoch 00191: saving model to ./model/191-0.0521.hdf5
#
# Epoch 00192: saving model to ./model/192-0.0503.hdf5
#
# Epoch 00193: saving model to ./model/193-0.0504.hdf5
#
# Epoch 00194: saving model to ./model/194-0.0511.hdf5
#
# Epoch 00195: saving model to ./model/195-0.0497.hdf5
#
# Epoch 00196: saving model to ./model/196-0.0538.hdf5
#
# Epoch 00197: saving model to ./model/197-0.0496.hdf5
#
# Epoch 00198: saving model to ./model/198-0.0504.hdf5
#
# Epoch 00199: saving model to ./model/199-0.0541.hdf5
#
# Epoch 00200: saving model to ./model/200-0.0524.hdf5
