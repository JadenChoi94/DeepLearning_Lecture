# %% [markdown]
# ### 17 x 30 x 1,
# ### relu, adam, 30, 20
# ### mean_squared_error
# ### 0.851

# %%
# 필요한 라이브러리를 불러옵니다.
import numpy as np
import tensorflow as tf
#툴툴거림방지
if type(tf.contrib) != type(tf):
    tf.contrib._warning = None
    
# 딥러닝을 구동하는 데 필요한 케라스 함수를 불러옵니다.
from keras.models import Sequential
from keras.layers import Dense

# 실행할 때마다 같은 결과를 출력하기 위해 설정하는 부분입니다.
seed = 0
np.random.seed(seed)
tf.set_random_seed(seed)

# 준비된 수술 환자 데이터를 불러들입니다.
Data_set = np.loadtxt('../../data/ThoraricSurgery.csv', delimiter=',')

# 환자의 기록과 수술 결과를 X와 Y로 구분하여 저장합니다.
X = Data_set[:,0:17]
Y = Data_set[:,17]

# 딥러닝 구조를 결정합니다(모델을 설정하고 실행하는 부분입니다).
model = Sequential()
model.add(Dense(12, input_dim=17, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 딥러닝을 실행합니다.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=30, batch_size=20)

# 결과를 출력합니다.
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0809 10:20:04.682409  4188 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0809 10:20:04.687409  4188 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0809 10:20:04.688409  4188 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0809 10:20:04.710411  4188 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0809 10:20:04.804416  4188 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0809 10:20:04.853419  4188 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Epoch 1/30
# 470/470 [==============================] - 0s 264us/step - loss: 0.8446 - acc: 0.1511
# Epoch 2/30
# 470/470 [==============================] - 0s 30us/step - loss: 0.8357 - acc: 0.1574
# Epoch 3/30
# 470/470 [==============================] - 0s 30us/step - loss: 0.8285 - acc: 0.1638
# Epoch 4/30
# 470/470 [==============================] - 0s 28us/step - loss: 0.8166 - acc: 0.1809
# Epoch 5/30
# 470/470 [==============================] - 0s 30us/step - loss: 0.8011 - acc: 0.1915
# Epoch 6/30
# 470/470 [==============================] - 0s 28us/step - loss: 0.7616 - acc: 0.2319
# Epoch 7/30
# 470/470 [==============================] - 0s 30us/step - loss: 0.4496 - acc: 0.5404
# Epoch 8/30
# 470/470 [==============================] - 0s 32us/step - loss: 0.1489 - acc: 0.8511
# Epoch 9/30
# 470/470 [==============================] - 0s 32us/step - loss: 0.1489 - acc: 0.8511
# Epoch 10/30
# 470/470 [==============================] - 0s 30us/step - loss: 0.1489 - acc: 0.8511
# Epoch 11/30
# 470/470 [==============================] - 0s 30us/step - loss: 0.1489 - acc: 0.8511
# Epoch 12/30
# 470/470 [==============================] - 0s 28us/step - loss: 0.1489 - acc: 0.8511
# Epoch 13/30
# 470/470 [==============================] - 0s 30us/step - loss: 0.1489 - acc: 0.8511
# Epoch 14/30
# 470/470 [==============================] - 0s 30us/step - loss: 0.1489 - acc: 0.8511
# Epoch 15/30
# 470/470 [==============================] - 0s 30us/step - loss: 0.1489 - acc: 0.8511
# Epoch 16/30
# 470/470 [==============================] - 0s 30us/step - loss: 0.1489 - acc: 0.8511
# Epoch 17/30
# 470/470 [==============================] - 0s 32us/step - loss: 0.1489 - acc: 0.8511
# Epoch 18/30
# 470/470 [==============================] - 0s 28us/step - loss: 0.1489 - acc: 0.8511
# Epoch 19/30
# 470/470 [==============================] - 0s 30us/step - loss: 0.1489 - acc: 0.8511
# Epoch 20/30
# 470/470 [==============================] - 0s 28us/step - loss: 0.1489 - acc: 0.8511
# Epoch 21/30
# 470/470 [==============================] - 0s 26us/step - loss: 0.1489 - acc: 0.8511
# Epoch 22/30
# 470/470 [==============================] - 0s 28us/step - loss: 0.1489 - acc: 0.8511
# Epoch 23/30
# 470/470 [==============================] - 0s 26us/step - loss: 0.1489 - acc: 0.8511
# Epoch 24/30
# 470/470 [==============================] - 0s 26us/step - loss: 0.1489 - acc: 0.8511
# Epoch 25/30
# 470/470 [==============================] - 0s 28us/step - loss: 0.1489 - acc: 0.8511
# Epoch 26/30
# 470/470 [==============================] - 0s 30us/step - loss: 0.1489 - acc: 0.8511
# Epoch 27/30
# 470/470 [==============================] - 0s 28us/step - loss: 0.1489 - acc: 0.8511
# Epoch 28/30
# 470/470 [==============================] - 0s 28us/step - loss: 0.1489 - acc: 0.8511
# Epoch 29/30
# 470/470 [==============================] - 0s 28us/step - loss: 0.1489 - acc: 0.8511
# Epoch 30/30
# 470/470 [==============================] - 0s 28us/step - loss: 0.1489 - acc: 0.8511
# 470/470 [==============================] - 0s 45us/step
#
#  Accuracy: 0.8511
