# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint

import pandas as pd
import numpy
import os
import tensorflow as tf

# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

df_pre = pd.read_csv('../data/wine.csv', header=None)
df = df_pre.sample(frac=1)

dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]
# Out:
# Using TensorFlow backend.

# %%
# 모델의 설정
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# 모델 저장 폴더 설정
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

# 모델 저장 조건 설정
modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True) #verbose 화면에 띄우때

# 모델 실행 및 저장
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])#verbose = 0  화면에 안띄운다.
# Out:
# Epoch 00001: val_loss improved from inf to 0.42450, saving model to ./model/01-0.4245.hdf5
#
# Epoch 00002: val_loss improved from 0.42450 to 0.31348, saving model to ./model/02-0.3135.hdf5
#
# Epoch 00003: val_loss improved from 0.31348 to 0.27287, saving model to ./model/03-0.2729.hdf5
#
# Epoch 00004: val_loss improved from 0.27287 to 0.22000, saving model to ./model/04-0.2200.hdf5
#
# Epoch 00005: val_loss improved from 0.22000 to 0.21198, saving model to ./model/05-0.2120.hdf5
#
# Epoch 00006: val_loss improved from 0.21198 to 0.20901, saving model to ./model/06-0.2090.hdf5
#
# Epoch 00007: val_loss improved from 0.20901 to 0.20809, saving model to ./model/07-0.2081.hdf5
#
# Epoch 00008: val_loss improved from 0.20809 to 0.20368, saving model to ./model/08-0.2037.hdf5
#
# Epoch 00009: val_loss improved from 0.20368 to 0.19966, saving model to ./model/09-0.1997.hdf5
#
# Epoch 00010: val_loss improved from 0.19966 to 0.19835, saving model to ./model/10-0.1984.hdf5
#
# Epoch 00011: val_loss improved from 0.19835 to 0.19654, saving model to ./model/11-0.1965.hdf5
#
# Epoch 00012: val_loss did not improve from 0.19654
#
# Epoch 00013: val_loss improved from 0.19654 to 0.19298, saving model to ./model/13-0.1930.hdf5
#
# Epoch 00014: val_loss did not improve from 0.19298
#
# Epoch 00015: val_loss did not improve from 0.19298
#
# Epoch 00016: val_loss improved from 0.19298 to 0.19148, saving model to ./model/16-0.1915.hdf5
#
# Epoch 00017: val_loss improved from 0.19148 to 0.19064, saving model to ./model/17-0.1906.hdf5
#
# Epoch 00018: val_loss improved from 0.19064 to 0.18657, saving model to ./model/18-0.1866.hdf5
#
# Epoch 00019: val_loss improved from 0.18657 to 0.18606, saving model to ./model/19-0.1861.hdf5
#
# Epoch 00020: val_loss did not improve from 0.18606
#
# Epoch 00021: val_loss improved from 0.18606 to 0.18184, saving model to ./model/21-0.1818.hdf5
#
# Epoch 00022: val_loss improved from 0.18184 to 0.17933, saving model to ./model/22-0.1793.hdf5
#
# Epoch 00023: val_loss improved from 0.17933 to 0.17856, saving model to ./model/23-0.1786.hdf5
#
# Epoch 00024: val_loss improved from 0.17856 to 0.17835, saving model to ./model/24-0.1784.hdf5
#
# Epoch 00025: val_loss improved from 0.17835 to 0.17550, saving model to ./model/25-0.1755.hdf5
#
# Epoch 00026: val_loss improved from 0.17550 to 0.17046, saving model to ./model/26-0.1705.hdf5
#
# Epoch 00027: val_loss did not improve from 0.17046
#
# Epoch 00028: val_loss improved from 0.17046 to 0.16470, saving model to ./model/28-0.1647.hdf5
#
# Epoch 00029: val_loss improved from 0.16470 to 0.16255, saving model to ./model/29-0.1625.hdf5
#
# Epoch 00030: val_loss improved from 0.16255 to 0.16219, saving model to ./model/30-0.1622.hdf5
#
# Epoch 00031: val_loss improved from 0.16219 to 0.15578, saving model to ./model/31-0.1558.hdf5
#
# Epoch 00032: val_loss improved from 0.15578 to 0.15084, saving model to ./model/32-0.1508.hdf5
#
# Epoch 00033: val_loss improved from 0.15084 to 0.14734, saving model to ./model/33-0.1473.hdf5
#
# Epoch 00034: val_loss improved from 0.14734 to 0.14411, saving model to ./model/34-0.1441.hdf5
#
# Epoch 00035: val_loss improved from 0.14411 to 0.14114, saving model to ./model/35-0.1411.hdf5
#
# Epoch 00036: val_loss improved from 0.14114 to 0.13780, saving model to ./model/36-0.1378.hdf5
#
# Epoch 00037: val_loss improved from 0.13780 to 0.13269, saving model to ./model/37-0.1327.hdf5
#
# Epoch 00038: val_loss improved from 0.13269 to 0.12724, saving model to ./model/38-0.1272.hdf5
#
# Epoch 00039: val_loss improved from 0.12724 to 0.12296, saving model to ./model/39-0.1230.hdf5
#
# Epoch 00040: val_loss did not improve from 0.12296
#
# Epoch 00041: val_loss improved from 0.12296 to 0.11177, saving model to ./model/41-0.1118.hdf5
#
# Epoch 00042: val_loss improved from 0.11177 to 0.10632, saving model to ./model/42-0.1063.hdf5
#
# Epoch 00043: val_loss improved from 0.10632 to 0.10019, saving model to ./model/43-0.1002.hdf5
#
# Epoch 00044: val_loss improved from 0.10019 to 0.09839, saving model to ./model/44-0.0984.hdf5
#
# Epoch 00045: val_loss improved from 0.09839 to 0.09526, saving model to ./model/45-0.0953.hdf5
#
# Epoch 00046: val_loss improved from 0.09526 to 0.09243, saving model to ./model/46-0.0924.hdf5
#
# Epoch 00047: val_loss improved from 0.09243 to 0.09066, saving model to ./model/47-0.0907.hdf5
#
# Epoch 00048: val_loss improved from 0.09066 to 0.08671, saving model to ./model/48-0.0867.hdf5
#
# Epoch 00049: val_loss improved from 0.08671 to 0.08396, saving model to ./model/49-0.0840.hdf5
#
# Epoch 00050: val_loss improved from 0.08396 to 0.08096, saving model to ./model/50-0.0810.hdf5
#
# Epoch 00051: val_loss did not improve from 0.08096
#
# Epoch 00052: val_loss improved from 0.08096 to 0.07848, saving model to ./model/52-0.0785.hdf5
#
# Epoch 00053: val_loss improved from 0.07848 to 0.07762, saving model to ./model/53-0.0776.hdf5
#
# Epoch 00054: val_loss improved from 0.07762 to 0.07669, saving model to ./model/54-0.0767.hdf5
#
# Epoch 00055: val_loss did not improve from 0.07669
#
# Epoch 00056: val_loss did not improve from 0.07669
#
# Epoch 00057: val_loss improved from 0.07669 to 0.07573, saving model to ./model/57-0.0757.hdf5
#
# Epoch 00058: val_loss did not improve from 0.07573
#
# Epoch 00059: val_loss improved from 0.07573 to 0.07488, saving model to ./model/59-0.0749.hdf5
#
# Epoch 00060: val_loss did not improve from 0.07488
#
# Epoch 00061: val_loss improved from 0.07488 to 0.06892, saving model to ./model/61-0.0689.hdf5
#
# Epoch 00062: val_loss improved from 0.06892 to 0.06828, saving model to ./model/62-0.0683.hdf5
#
# Epoch 00063: val_loss did not improve from 0.06828
#
# Epoch 00064: val_loss improved from 0.06828 to 0.06785, saving model to ./model/64-0.0679.hdf5
#
# Epoch 00065: val_loss did not improve from 0.06785
#
# Epoch 00066: val_loss improved from 0.06785 to 0.06610, saving model to ./model/66-0.0661.hdf5
#
# Epoch 00067: val_loss did not improve from 0.06610
#
# Epoch 00068: val_loss improved from 0.06610 to 0.06529, saving model to ./model/68-0.0653.hdf5
#
# Epoch 00069: val_loss improved from 0.06529 to 0.06346, saving model to ./model/69-0.0635.hdf5
#
# Epoch 00070: val_loss did not improve from 0.06346
#
# Epoch 00071: val_loss improved from 0.06346 to 0.06324, saving model to ./model/71-0.0632.hdf5
#
# Epoch 00072: val_loss did not improve from 0.06324
#
# Epoch 00073: val_loss improved from 0.06324 to 0.06190, saving model to ./model/73-0.0619.hdf5
#
# Epoch 00074: val_loss improved from 0.06190 to 0.06137, saving model to ./model/74-0.0614.hdf5
#
# Epoch 00075: val_loss did not improve from 0.06137
#
# Epoch 00076: val_loss improved from 0.06137 to 0.06095, saving model to ./model/76-0.0609.hdf5
#
# Epoch 00077: val_loss improved from 0.06095 to 0.06030, saving model to ./model/77-0.0603.hdf5
#
# Epoch 00078: val_loss did not improve from 0.06030
#
# Epoch 00079: val_loss did not improve from 0.06030
#
# Epoch 00080: val_loss did not improve from 0.06030
#
# Epoch 00081: val_loss did not improve from 0.06030
#
# Epoch 00082: val_loss improved from 0.06030 to 0.05932, saving model to ./model/82-0.0593.hdf5
#
# Epoch 00083: val_loss improved from 0.05932 to 0.05740, saving model to ./model/83-0.0574.hdf5
#
# Epoch 00084: val_loss did not improve from 0.05740
#
# Epoch 00085: val_loss did not improve from 0.05740
#
# Epoch 00086: val_loss did not improve from 0.05740
#
# Epoch 00087: val_loss improved from 0.05740 to 0.05734, saving model to ./model/87-0.0573.hdf5
#
# Epoch 00088: val_loss did not improve from 0.05734
#
# Epoch 00089: val_loss did not improve from 0.05734
#
# Epoch 00090: val_loss did not improve from 0.05734
#
# Epoch 00091: val_loss did not improve from 0.05734
#
# Epoch 00092: val_loss did not improve from 0.05734
#
# Epoch 00093: val_loss improved from 0.05734 to 0.05549, saving model to ./model/93-0.0555.hdf5
#
# Epoch 00094: val_loss improved from 0.05549 to 0.05485, saving model to ./model/94-0.0548.hdf5
#
# Epoch 00095: val_loss did not improve from 0.05485
#
# Epoch 00096: val_loss did not improve from 0.05485
#
# Epoch 00097: val_loss did not improve from 0.05485
#
# Epoch 00098: val_loss improved from 0.05485 to 0.05458, saving model to ./model/98-0.0546.hdf5
#
# Epoch 00099: val_loss did not improve from 0.05458
#
# Epoch 00100: val_loss did not improve from 0.05458
#
# Epoch 00101: val_loss did not improve from 0.05458
# Epoch 00102: val_loss did not improve from 0.05458
#
# Epoch 00103: val_loss did not improve from 0.05458
#
# Epoch 00104: val_loss improved from 0.05458 to 0.05433, saving model to ./model/104-0.0543.hdf5
#
# Epoch 00105: val_loss improved from 0.05433 to 0.05333, saving model to ./model/105-0.0533.hdf5
#
# Epoch 00106: val_loss did not improve from 0.05333
#
# Epoch 00107: val_loss did not improve from 0.05333
#
# Epoch 00108: val_loss improved from 0.05333 to 0.05301, saving model to ./model/108-0.0530.hdf5
#
# Epoch 00109: val_loss did not improve from 0.05301
#
# Epoch 00110: val_loss did not improve from 0.05301
#
# Epoch 00111: val_loss did not improve from 0.05301
#
# Epoch 00112: val_loss did not improve from 0.05301
#
# Epoch 00113: val_loss improved from 0.05301 to 0.05237, saving model to ./model/113-0.0524.hdf5
#
# Epoch 00114: val_loss did not improve from 0.05237
#
# Epoch 00115: val_loss did not improve from 0.05237
#
# Epoch 00116: val_loss did not improve from 0.05237
#
# Epoch 00117: val_loss did not improve from 0.05237
#
# Epoch 00118: val_loss improved from 0.05237 to 0.05217, saving model to ./model/118-0.0522.hdf5
#
# Epoch 00119: val_loss did not improve from 0.05217
#
# Epoch 00120: val_loss did not improve from 0.05217
#
# Epoch 00121: val_loss did not improve from 0.05217
#
# Epoch 00122: val_loss did not improve from 0.05217
#
# Epoch 00123: val_loss improved from 0.05217 to 0.05147, saving model to ./model/123-0.0515.hdf5
#
# Epoch 00124: val_loss did not improve from 0.05147
#
# Epoch 00125: val_loss did not improve from 0.05147
#
# Epoch 00126: val_loss did not improve from 0.05147
#
# Epoch 00127: val_loss did not improve from 0.05147
#
# Epoch 00128: val_loss did not improve from 0.05147
#
# Epoch 00129: val_loss did not improve from 0.05147
#
# Epoch 00130: val_loss did not improve from 0.05147
#
# Epoch 00131: val_loss did not improve from 0.05147
#
# Epoch 00132: val_loss improved from 0.05147 to 0.05092, saving model to ./model/132-0.0509.hdf5
#
# Epoch 00133: val_loss did not improve from 0.05092
#
# Epoch 00134: val_loss did not improve from 0.05092
#
# Epoch 00135: val_loss improved from 0.05092 to 0.05074, saving model to ./model/135-0.0507.hdf5
#
# Epoch 00136: val_loss did not improve from 0.05074
#
# Epoch 00137: val_loss did not improve from 0.05074
#
# Epoch 00138: val_loss did not improve from 0.05074
#
# Epoch 00139: val_loss did not improve from 0.05074
#
# Epoch 00140: val_loss did not improve from 0.05074
#
# Epoch 00141: val_loss did not improve from 0.05074
#
# Epoch 00142: val_loss did not improve from 0.05074
#
# Epoch 00143: val_loss did not improve from 0.05074
#
# Epoch 00144: val_loss did not improve from 0.05074
#
# Epoch 00145: val_loss improved from 0.05074 to 0.05037, saving model to ./model/145-0.0504.hdf5
#
# Epoch 00146: val_loss did not improve from 0.05037
#
# Epoch 00147: val_loss did not improve from 0.05037
#
# Epoch 00148: val_loss did not improve from 0.05037
#
# Epoch 00149: val_loss did not improve from 0.05037
#
# Epoch 00150: val_loss did not improve from 0.05037
#
# Epoch 00151: val_loss did not improve from 0.05037
#
# Epoch 00152: val_loss improved from 0.05037 to 0.05037, saving model to ./model/152-0.0504.hdf5
#
# Epoch 00153: val_loss did not improve from 0.05037
#
# Epoch 00154: val_loss did not improve from 0.05037
#
# Epoch 00155: val_loss did not improve from 0.05037
#
# Epoch 00156: val_loss improved from 0.05037 to 0.04995, saving model to ./model/156-0.0499.hdf5
#
# Epoch 00157: val_loss did not improve from 0.04995
#
# Epoch 00158: val_loss did not improve from 0.04995
#
# Epoch 00159: val_loss did not improve from 0.04995
#
# Epoch 00160: val_loss did not improve from 0.04995
#
# Epoch 00161: val_loss did not improve from 0.04995
#
# Epoch 00162: val_loss did not improve from 0.04995
#
# Epoch 00163: val_loss improved from 0.04995 to 0.04939, saving model to ./model/163-0.0494.hdf5
#
# Epoch 00164: val_loss did not improve from 0.04939
#
# Epoch 00165: val_loss did not improve from 0.04939
#
# Epoch 00166: val_loss did not improve from 0.04939
#
# Epoch 00167: val_loss did not improve from 0.04939
#
# Epoch 00168: val_loss did not improve from 0.04939
#
# Epoch 00169: val_loss did not improve from 0.04939
#
# Epoch 00170: val_loss did not improve from 0.04939
#
# Epoch 00171: val_loss did not improve from 0.04939
#
# Epoch 00172: val_loss did not improve from 0.04939
#
# Epoch 00173: val_loss did not improve from 0.04939
#
# Epoch 00174: val_loss did not improve from 0.04939
#
# Epoch 00175: val_loss did not improve from 0.04939
#
# Epoch 00176: val_loss did not improve from 0.04939
#
# Epoch 00177: val_loss did not improve from 0.04939
#
# Epoch 00178: val_loss improved from 0.04939 to 0.04890, saving model to ./model/178-0.0489.hdf5
#
# Epoch 00179: val_loss did not improve from 0.04890
#
# Epoch 00180: val_loss did not improve from 0.04890
#
# Epoch 00181: val_loss did not improve from 0.04890
#
# Epoch 00182: val_loss did not improve from 0.04890
#
# Epoch 00183: val_loss improved from 0.04890 to 0.04837, saving model to ./model/183-0.0484.hdf5
#
# Epoch 00184: val_loss did not improve from 0.04837
#
# Epoch 00185: val_loss did not improve from 0.04837
#
# Epoch 00186: val_loss did not improve from 0.04837
#
# Epoch 00187: val_loss did not improve from 0.04837
#
# Epoch 00188: val_loss did not improve from 0.04837
#
# Epoch 00189: val_loss did not improve from 0.04837
#
# Epoch 00190: val_loss did not improve from 0.04837
#
# Epoch 00191: val_loss did not improve from 0.04837
#
# Epoch 00192: val_loss did not improve from 0.04837
#
# Epoch 00193: val_loss did not improve from 0.04837
#
# Epoch 00194: val_loss did not improve from 0.04837
#
# Epoch 00195: val_loss did not improve from 0.04837
#
# Epoch 00196: val_loss did not improve from 0.04837
#
# Epoch 00197: val_loss did not improve from 0.04837
#
# Epoch 00198: val_loss did not improve from 0.04837
#
# Epoch 00199: val_loss did not improve from 0.04837
#
# Epoch 00200: val_loss did not improve from 0.04837
